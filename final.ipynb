# %% [markdown]
# # Algoritmos de Busca - Resultados finais

# %% [markdown]
# ### Imports

# %%
from aigyminsper.search.SearchAlgorithms import BuscaLargura
from aigyminsper.search.SearchAlgorithms import BuscaProfundidade
from aigyminsper.search.SearchAlgorithms import BuscaProfundidadeIterativa
from aigyminsper.search.Graph import State
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Algoritmo - Busca em Profundidade (limite = 10)

# %%
class SumOne(State):

    def __init__(self, n, op, g):
        self.operator = op
        self.number = n
        self.goal = g

    def sucessors(self):
        sucessors = []
        if self.number < self.goal:
            sucessors.append(SumOne(self.number+1, "+1 ", self.goal))
            sucessors.append(SumOne(self.number+2, "+2 ", self.goal))
        return sucessors

    def is_goal(self):
        if self.goal == self.number:
            return True
        return False

    def description(self):
        return "Este é um agente simples que sabe somar 1 e 2"

    def cost(self):
        return 1

    def env(self):
        return self.number
    
def main():
    # criar um DataFrame para armazenar os resultados
    df = pd.DataFrame(columns=['Algoritmo', 'Objetivo', 'Tempo de processamento', 'Achou solucao?'])

    # definir os valores iniciais
    start = 1
    end = 50

    for objetivo in range(start, end+1):
        state = SumOne(1, '', objetivo)
        algorithm = BuscaProfundidade()
        start_time = datetime.now()
        result = algorithm.search(state, 10)
        end_time = datetime.now()
        tempo = (end_time - start_time).microseconds
        if result != None:
            pass
        else:
            pass
        # colocar os resultados no df
        df.loc[len(df)] = ['Busca em Profundidade (m=10)', objetivo, tempo, result != None]

    # salvar o df em um arquivo csv
    df.to_csv('dados_profundidade_10.csv', index=False)

if __name__ == '__main__':
    main()

# %% [markdown]
# #### Tabela - Busca em Profundidade (limite = 10)

# %%
df_profundidade_10 = pd.read_csv('dados_profundidade_10.csv')
df_profundidade_10
# Out:
#                        Algoritmo  Objetivo  Tempo de processamento  \
# 0   Busca em Profundidade (m=10)         1                       0
# 1   Busca em Profundidade (m=10)         2                       0
# 2   Busca em Profundidade (m=10)         3                       0
# 3   Busca em Profundidade (m=10)         4                       0
# 4   Busca em Profundidade (m=10)         5                       0
# 5   Busca em Profundidade (m=10)         6                       0
# 6   Busca em Profundidade (m=10)         7                       0
# 7   Busca em Profundidade (m=10)         8                       0
# 8   Busca em Profundidade (m=10)         9                       0
# 9   Busca em Profundidade (m=10)        10                       0
# 10  Busca em Profundidade (m=10)        11                       0
# 11  Busca em Profundidade (m=10)        12                       0
# 12  Busca em Profundidade (m=10)        13                       0
# 13  Busca em Profundidade (m=10)        14                       0
# 14  Busca em Profundidade (m=10)        15                       0
# 15  Busca em Profundidade (m=10)        16                       0
# 16  Busca em Profundidade (m=10)        17                       0
# 17  Busca em Profundidade (m=10)        18                       0
# 18  Busca em Profundidade (m=10)        19                       0
# 19  Busca em Profundidade (m=10)        20                       0
# 20  Busca em Profundidade (m=10)        21                       0
# 21  Busca em Profundidade (m=10)        22                    1001
# 22  Busca em Profundidade (m=10)        23                    1000
# 23  Busca em Profundidade (m=10)        24                    1000
# 24  Busca em Profundidade (m=10)        25                    1000
# 25  Busca em Profundidade (m=10)        26                    1061
# 26  Busca em Profundidade (m=10)        27                     941
# 27  Busca em Profundidade (m=10)        28                    1000
# 28  Busca em Profundidade (m=10)        29                    1001
# 29  Busca em Profundidade (m=10)        30                    1000
# 30  Busca em Profundidade (m=10)        31                    2001
# 31  Busca em Profundidade (m=10)        32                     999
# 32  Busca em Profundidade (m=10)        33                     948
# 33  Busca em Profundidade (m=10)        34                    1001
# 34  Busca em Profundidade (m=10)        35                     999
# 35  Busca em Profundidade (m=10)        36                    1001
# 36  Busca em Profundidade (m=10)        37                    1000
# 37  Busca em Profundidade (m=10)        38                    1000
# 38  Busca em Profundidade (m=10)        39                    1001
# 39  Busca em Profundidade (m=10)        40                    1001
# 40  Busca em Profundidade (m=10)        41                    1000
# 41  Busca em Profundidade (m=10)        42                    1000
# 42  Busca em Profundidade (m=10)        43                    1001
# 43  Busca em Profundidade (m=10)        44                    1000
# 44  Busca em Profundidade (m=10)        45                    1000
# 45  Busca em Profundidade (m=10)        46                    2001
# 46  Busca em Profundidade (m=10)        47                    1000
# 47  Busca em Profundidade (m=10)        48                    1001
# 48  Busca em Profundidade (m=10)        49                    1000
# 49  Busca em Profundidade (m=10)        50                    1000
#
#     Achou solucao?
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# 6             True
# 7             True
# 8             True
# 9             True
# 10            True
# 11            True
# 12            True
# 13            True
# 14            True
# 15            True
# 16            True
# 17            True
# 18            True
# 19            True
# 20            True
# 21           False
# 22           False
# 23           False
# 24           False
# 25           False
# 26           False
# 27           False
# 28           False
# 29           False
# 30           False
# 31           False
# 32           False
# 33           False
# 34           False
# 35           False
# 36           False
# 37           False
# 38           False
# 39           False
# 40           False
# 41           False
# 42           False
# 43           False
# 44           False
# 45           False
# 46           False
# 47           False
# 48           False
# 49           False

# %% [markdown]
# #### Gráfico dos resultados - Busca em Profundidade (limite = 10)

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_profundidade_10['Objetivo'], df_profundidade_10['Tempo de processamento'])
plt.xlabel('Objetivo')
plt.ylabel('Tempo de processamento (microsegundos)')
plt.title('Busca em Profundidade com limite de 10')
plt.show()

# %% [markdown]
# ### Algoritmo - Busca em Profundidade (limite = 100)

# %%
class SumOne(State):

    def __init__(self, n, op, g):
        self.operator = op
        self.number = n
        self.goal = g

    def sucessors(self):
        sucessors = []
        if self.number < self.goal:
            sucessors.append(SumOne(self.number+1, "+1 ", self.goal))
            sucessors.append(SumOne(self.number+2, "+2 ", self.goal))
        return sucessors

    def is_goal(self):
        if self.goal == self.number:
            return True
        return False

    def description(self):
        return "Este é um agente simples que sabe somar 1 e 2"

    def cost(self):
        return 1

    def env(self):
        return self.number
    
def main():
    # criar um DataFrame para armazenar os resultados
    df = pd.DataFrame(columns=['Algoritmo', 'Objetivo', 'Tempo de processamento', 'Achou solucao?'])

    # definir os valores iniciais
    start = 1
    end = 50

    for objetivo in range(start, end+1):
        state = SumOne(1, '', objetivo)
        algorithm = BuscaProfundidade()
        start_time = datetime.now()
        result = algorithm.search(state, 100)
        end_time = datetime.now()
        tempo = (end_time - start_time).microseconds
        if result != None:
            pass
        else:
            pass
        # colocar os resultados no df
        df.loc[len(df)] = ['Busca em Profundidade (m=100)', objetivo, tempo, result != None]

    # salvar o df em um arquivo csv
    df.to_csv('dados_profundidade_100.csv', index=False)

if __name__ == '__main__':
    main()

# %% [markdown]
# ### Tabela - Busca em Profundidade (limite = 100)

# %%
df_profundidade_100 = pd.read_csv('dados_profundidade_100.csv')
df_profundidade_100
# Out:
#                         Algoritmo  Objetivo  Tempo de processamento  \
# 0   Busca em Profundidade (m=100)         1                       0
# 1   Busca em Profundidade (m=100)         2                       0
# 2   Busca em Profundidade (m=100)         3                       0
# 3   Busca em Profundidade (m=100)         4                       0
# 4   Busca em Profundidade (m=100)         5                       0
# 5   Busca em Profundidade (m=100)         6                       0
# 6   Busca em Profundidade (m=100)         7                       0
# 7   Busca em Profundidade (m=100)         8                       0
# 8   Busca em Profundidade (m=100)         9                       0
# 9   Busca em Profundidade (m=100)        10                       0
# 10  Busca em Profundidade (m=100)        11                       0
# 11  Busca em Profundidade (m=100)        12                       0
# 12  Busca em Profundidade (m=100)        13                       0
# 13  Busca em Profundidade (m=100)        14                       0
# 14  Busca em Profundidade (m=100)        15                       0
# 15  Busca em Profundidade (m=100)        16                       0
# 16  Busca em Profundidade (m=100)        17                       0
# 17  Busca em Profundidade (m=100)        18                       0
# 18  Busca em Profundidade (m=100)        19                       0
# 19  Busca em Profundidade (m=100)        20                       0
# 20  Busca em Profundidade (m=100)        21                       0
# 21  Busca em Profundidade (m=100)        22                       0
# 22  Busca em Profundidade (m=100)        23                       0
# 23  Busca em Profundidade (m=100)        24                       0
# 24  Busca em Profundidade (m=100)        25                       0
# 25  Busca em Profundidade (m=100)        26                       0
# 26  Busca em Profundidade (m=100)        27                       0
# 27  Busca em Profundidade (m=100)        28                       0
# 28  Busca em Profundidade (m=100)        29                       0
# 29  Busca em Profundidade (m=100)        30                       0
# 30  Busca em Profundidade (m=100)        31                       0
# 31  Busca em Profundidade (m=100)        32                       0
# 32  Busca em Profundidade (m=100)        33                       0
# 33  Busca em Profundidade (m=100)        34                       0
# 34  Busca em Profundidade (m=100)        35                       0
# 35  Busca em Profundidade (m=100)        36                       0
# 36  Busca em Profundidade (m=100)        37                       0
# 37  Busca em Profundidade (m=100)        38                       0
# 38  Busca em Profundidade (m=100)        39                       0
# 39  Busca em Profundidade (m=100)        40                       0
# 40  Busca em Profundidade (m=100)        41                       0
# 41  Busca em Profundidade (m=100)        42                       0
# 42  Busca em Profundidade (m=100)        43                       0
# 43  Busca em Profundidade (m=100)        44                       0
# 44  Busca em Profundidade (m=100)        45                       0
# 45  Busca em Profundidade (m=100)        46                       0
# 46  Busca em Profundidade (m=100)        47                    1000
# 47  Busca em Profundidade (m=100)        48                       0
# 48  Busca em Profundidade (m=100)        49                       0
# 49  Busca em Profundidade (m=100)        50                       0
#
#     Achou solucao?
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# 6             True
# 7             True
# 8             True
# 9             True
# 10            True
# 11            True
# 12            True
# 13            True
# 14            True
# 15            True
# 16            True
# 17            True
# 18            True
# 19            True
# 20            True
# 21            True
# 22            True
# 23            True
# 24            True
# 25            True
# 26            True
# 27            True
# 28            True
# 29            True
# 30            True
# 31            True
# 32            True
# 33            True
# 34            True
# 35            True
# 36            True
# 37            True
# 38            True
# 39            True
# 40            True
# 41            True
# 42            True
# 43            True
# 44            True
# 45            True
# 46            True
# 47            True
# 48            True
# 49            True

# %% [markdown]
# #### Gráfico dos resultados - Busca em Profundidade (limite = 100)

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_profundidade_100['Objetivo'], df_profundidade_100['Tempo de processamento'])
plt.xlabel('Objetivo')
plt.ylabel('Tempo de processamento (microsegundos)')
plt.title('Busca em Profundidade com limite de 100')
plt.show()

# %% [markdown]
# ### Algoritmo - Busca em Largura

# %%
class SumOne(State):

    def __init__(self, n, op, g):
        self.operator = op
        self.number = n
        self.goal = g

    def sucessors(self):
        sucessors = []
        if self.number < self.goal:
            sucessors.append(SumOne(self.number+1, "+1 ", self.goal))
            sucessors.append(SumOne(self.number+2, "+2 ", self.goal))
        return sucessors

    def is_goal(self):
        if self.goal == self.number:
            return True
        return False

    def description(self):
        return "Este é um agente simples que sabe somar 1 e 2"

    def cost(self):
        return 1

    def env(self):
        return self.number
    
def main():
    # criar um DataFrame para armazenar os resultados
    df = pd.DataFrame(columns=['Algoritmo', 'Objetivo', 'Tempo de processamento', 'Achou solucao?'])

    # definir os valores iniciais
    start = 1
    end = 50

    for objetivo in range(start, end+1):
        state = SumOne(1, '', objetivo)
        algorithm = BuscaLargura()
        start_time = datetime.now()
        result = algorithm.search(state)
        end_time = datetime.now()
        tempo = (end_time - start_time).microseconds
        if result != None:
            pass
        else:
            pass
        # colocar os resultados no df
        df.loc[len(df)] = ['Busca em Largura', objetivo, tempo, result != None]

    # salvar o df em um arquivo csv
    df.to_csv('dados_largura.csv', index=False)

if __name__ == '__main__':
    main()

# %% [markdown]
# ### Tabela - Busca em Largura

# %%
df_largura = pd.read_csv('dados_largura.csv')
df_largura
# Out:
#            Algoritmo  Objetivo  Tempo de processamento  Achou solucao?
# 0   Busca em Largura         1                       0            True
# 1   Busca em Largura         2                       0            True
# 2   Busca em Largura         3                       0            True
# 3   Busca em Largura         4                       0            True
# 4   Busca em Largura         5                       0            True
# 5   Busca em Largura         6                       0            True
# 6   Busca em Largura         7                       0            True
# 7   Busca em Largura         8                       0            True
# 8   Busca em Largura         9                       0            True
# 9   Busca em Largura        10                       0            True
# 10  Busca em Largura        11                       0            True
# 11  Busca em Largura        12                    1000            True
# 12  Busca em Largura        13                       0            True
# 13  Busca em Largura        14                       0            True
# 14  Busca em Largura        15                       0            True
# 15  Busca em Largura        16                       0            True
# 16  Busca em Largura        17                       0            True
# 17  Busca em Largura        18                    1001            True
# 18  Busca em Largura        19                    2000            True
# 19  Busca em Largura        20                    3001            True
# 20  Busca em Largura        21                    3014            True
# 21  Busca em Largura        22                    3000            True
# 22  Busca em Largura        23                    5001            True
# 23  Busca em Largura        24                    9001            True
# 24  Busca em Largura        25                   10003            True
# 25  Busca em Largura        26                   15003            True
# 26  Busca em Largura        27                   19004            True
# 27  Busca em Largura        28                   29007            True
# 28  Busca em Largura        29                   40009            True
# 29  Busca em Largura        30                   62128            True
# 30  Busca em Largura        31                   88453            True
# 31  Busca em Largura        32                  126548            True
# 32  Busca em Largura        33                  178580            True
# 33  Busca em Largura        34                  252514            True
# 34  Busca em Largura        35                  361617            True
# 35  Busca em Largura        36                  511786            True
# 36  Busca em Largura        37                  683539            True
# 37  Busca em Largura        38                    7919            True
# 38  Busca em Largura        39                  827539            True
# 39  Busca em Largura        40                   49893            True
# 40  Busca em Largura        41                  597801            True
# 41  Busca em Largura        42                  517354            True
# 42  Busca em Largura        43                  862308            True
# 43  Busca em Largura        44                  344892            True
# 44  Busca em Largura        45                  492706            True
# 45  Busca em Largura        46                  985837            True
# 46  Busca em Largura        47                  329592            True
# 47  Busca em Largura        48                  398434            True
# 48  Busca em Largura        49                  410798            True
# 49  Busca em Largura        50                  300212            True

# %% [markdown]
# #### Gráfico dos resultados - Busca em Largura

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_largura['Objetivo'], df_largura['Tempo de processamento'])
plt.xlabel('Objetivo')
plt.ylabel('Tempo de processamento (microsegundos)')
plt.title('Busca em Largura')
plt.show()

# %% [markdown]
# ### Algoritmo - Busca em Profundidade Iterativa

# %%
class SumOne(State):

    def __init__(self, n, op, g):
        self.operator = op
        self.number = n
        self.goal = g

    def sucessors(self):
        sucessors = []
        if self.number < self.goal:
            sucessors.append(SumOne(self.number+1, "+1 ", self.goal))
            sucessors.append(SumOne(self.number+2, "+2 ", self.goal))
        return sucessors

    def is_goal(self):
        if self.goal == self.number:
            return True
        return False

    def description(self):
        return "Este é um agente simples que sabe somar 1 e 2"

    def cost(self):
        return 1

    def env(self):
        return self.number
    
def main():
    # criar um DataFrame para armazenar os resultados
    df = pd.DataFrame(columns=['Algoritmo', 'Objetivo', 'Tempo de processamento', 'Achou solucao?'])

    # definir os valores iniciais
    start = 1
    end = 50

    for objetivo in range(start, end+1):
        state = SumOne(1, '', objetivo)
        algorithm = BuscaProfundidadeIterativa()
        start_time = datetime.now()
        result = algorithm.search(state)
        end_time = datetime.now()
        tempo = (end_time - start_time).microseconds
        if result != None:
            pass
        else:
            pass
        # colocar os resultados no df
        df.loc[len(df)] = ['Busca em Profundidade Iterativa', objetivo, tempo, result != None]

    # salvar o df em um arquivo csv
    df.to_csv('dados_profundidade_iterativa.csv', index=False)

if __name__ == '__main__':
    main()

# %% [markdown]
# ### Tabela - Busca em Profundidade Iterativa

# %%
df_profundidade_iterativa = pd.read_csv('dados_profundidade_iterativa.csv')
df_profundidade_iterativa
# Out:
#                           Algoritmo  Objetivo  Tempo de processamento  \
# 0   Busca em Profundidade Iterativa         1                       0
# 1   Busca em Profundidade Iterativa         2                       0
# 2   Busca em Profundidade Iterativa         3                       0
# 3   Busca em Profundidade Iterativa         4                       0
# 4   Busca em Profundidade Iterativa         5                       0
# 5   Busca em Profundidade Iterativa         6                       0
# 6   Busca em Profundidade Iterativa         7                       0
# 7   Busca em Profundidade Iterativa         8                       0
# 8   Busca em Profundidade Iterativa         9                       0
# 9   Busca em Profundidade Iterativa        10                       0
# 10  Busca em Profundidade Iterativa        11                       0
# 11  Busca em Profundidade Iterativa        12                       0
# 12  Busca em Profundidade Iterativa        13                       0
# 13  Busca em Profundidade Iterativa        14                       0
# 14  Busca em Profundidade Iterativa        15                    1000
# 15  Busca em Profundidade Iterativa        16                       0
# 16  Busca em Profundidade Iterativa        17                    1000
# 17  Busca em Profundidade Iterativa        18                    1000
# 18  Busca em Profundidade Iterativa        19                       0
# 19  Busca em Profundidade Iterativa        20                    1000
# 20  Busca em Profundidade Iterativa        21                    1001
# 21  Busca em Profundidade Iterativa        22                    3000
# 22  Busca em Profundidade Iterativa        23                    3001
# 23  Busca em Profundidade Iterativa        24                    5001
# 24  Busca em Profundidade Iterativa        25                    4001
# 25  Busca em Profundidade Iterativa        26                    9002
# 26  Busca em Profundidade Iterativa        27                    8002
# 27  Busca em Profundidade Iterativa        28                   17004
# 28  Busca em Profundidade Iterativa        29                   17003
# 29  Busca em Profundidade Iterativa        30                   35008
# 30  Busca em Profundidade Iterativa        31                   35022
# 31  Busca em Profundidade Iterativa        32                   68408
# 32  Busca em Profundidade Iterativa        33                   68524
# 33  Busca em Profundidade Iterativa        34                  134029
# 34  Busca em Profundidade Iterativa        35                  136544
# 35  Busca em Profundidade Iterativa        36                  272882
# 36  Busca em Profundidade Iterativa        37                  276586
# 37  Busca em Profundidade Iterativa        38                  541335
# 38  Busca em Profundidade Iterativa        39                  530790
# 39  Busca em Profundidade Iterativa        40                   69217
# 40  Busca em Profundidade Iterativa        41                   79878
# 41  Busca em Profundidade Iterativa        42                  140913
# 42  Busca em Profundidade Iterativa        43                  147139
# 43  Busca em Profundidade Iterativa        44                  279061
# 44  Busca em Profundidade Iterativa        45                  279807
# 45  Busca em Profundidade Iterativa        46                  516591
# 46  Busca em Profundidade Iterativa        47                  630559
# 47  Busca em Profundidade Iterativa        48                  140354
# 48  Busca em Profundidade Iterativa        49                  143290
# 49  Busca em Profundidade Iterativa        50                  329724
#
#     Achou solucao?
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# 6             True
# 7             True
# 8             True
# 9             True
# 10            True
# 11            True
# 12            True
# 13            True
# 14            True
# 15            True
# 16            True
# 17            True
# 18            True
# 19            True
# 20            True
# 21            True
# 22            True
# 23            True
# 24            True
# 25            True
# 26            True
# 27            True
# 28            True
# 29            True
# 30            True
# 31            True
# 32            True
# 33            True
# 34            True
# 35            True
# 36            True
# 37            True
# 38            True
# 39            True
# 40            True
# 41            True
# 42            True
# 43            True
# 44            True
# 45            True
# 46            True
# 47            True
# 48            True
# 49            True

# %% [markdown]
# #### Gráfico dos resultados - Busca em Profundidade Iterativa

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_profundidade_iterativa['Objetivo'], df_profundidade_iterativa['Tempo de processamento'])
plt.xlabel('Objetivo')
plt.ylabel('Tempo de processamento (microsegundos)')
plt.title('Busca em Profundidade Iterativa')
plt.show()

# %% [markdown]
# ### Gráfico final

# %%
plt.figure(figsize=(20, 7))
plt.plot(df_largura['Objetivo'], df_largura['Tempo de processamento'], label='Busca em Largura', color='red')
plt.plot(df_profundidade_10['Objetivo'], df_profundidade_10['Tempo de processamento'], label='Busca em Profundidade com limite de 10', color='blue')
plt.plot(df_profundidade_100['Objetivo'], df_profundidade_100['Tempo de processamento'], label='Busca em Profundidade com limite de 100', color='green')
plt.plot(df_profundidade_iterativa['Objetivo'], df_profundidade_iterativa['Tempo de processamento'], label='Busca em Profundidade Iterativa', color='orange')
plt.xlabel('Objetivo')
plt.ylabel('Tempo de processamento (microsegundos)')
plt.title('Comparação entre os algoritmos de busca')
plt.legend()
plt.show()

# %% [markdown]
# ## Segundo o que discutimos em sala de aula, quais destes algoritmos são ótimos? Os resultado encontrados neste exercício são coerentes com está informação? Justifique a sua resposta.
#
# #### Algoritmo Ótimo -> encontra a solução de menor custo
#
# R: Segundo o que foi discutido em sala de aula, os algoritmos que podem ser considerados ótimos são os de **largura** e de **profundidade iterativa**, já que analisam todas as possibilidades possíveis, enquanto que os algoritmos de **profundidade** são limitados por uma constante *m*, que nesse trabalho assumiu os valores de 10 e de 100.

# %% [markdown]
# ## Segundo o que discutimos em sala de aula, quais destes algoritmos são completos? Os resultado encontrados neste exercício são coerentes com está informação? Justifique a sua resposta.

# %% [markdown]
# #### Algoritmo Completo -> encontra a solução se ela existir

# %% [markdown]
# R: Segundo o que foi discutido em sala de aula, os algoritmos que podem ser considerados completos são os de **largura** e de **profundidade iterativa**, já que, enquanto estes analisam todas as possibilidades, os algoritmos de **profundidade** são limitados por uma constante que representa o nível de profundidade a qual o algoritmo vai percorrer, o que pode impedir do algoritmo encontrar a resposta, já que, caso ela esteja em um nível de profundidade maior que o limite estabelecido, o algoritmo não será capaz de encontrar uma solução.

# %% [markdown]
# ## Teve algum algoritmo que travou por falta de memória no seu computador? Se sim, qual é a explicação?
#
# R: Nenhum algoritmo chegou a travar por falta de memória em meu computador

# %% [markdown]
# ## Qual é o algoritmo que tem um tempo de processamento menor? Justifique a sua resposta.
#
# R: O algoritmo que apresentou o menor tempo de processamento foi o de **profundidade**. Isso se deve ao fato de este algoritmo precisar explorar menos nodos, ou seja, ele não percorre a árvore inteira para encontrar o resultado.
